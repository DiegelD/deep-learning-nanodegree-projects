# %% [markdown]
# # Face Generation
#
# In this project, you'll define and train a DCGAN on a dataset of faces. Your goal is to get a generator network to generate *new* images of faces that look as realistic as possible!
#
# The project will be broken down into a series of tasks from **loading in data to defining and training adversarial networks**. At the end of the notebook, you'll be able to visualize the results of your trained Generator to see how it performs; your generated samples should look like fairly realistic faces with small amounts of noise.
#
# ### Get the Data
#
# You'll be using the [CelebFaces Attributes Dataset (CelebA)](http://mmlab.ie.cuhk.edu.hk/projects/CelebA.html) to train your adversarial networks.
#
# This dataset is more complex than the number datasets (like MNIST or SVHN) you've been working with, and so, you should prepare to define deeper networks and train them for a longer time to get good results. It is suggested that you utilize a GPU for training.
#
# ### Pre-processed Data
#
# Since the project's main focus is on building the GANs, we've done *some* of the pre-processing for you. Each of the CelebA images has been cropped to remove parts of the image that don't include a face, then resized down to 64x64x3 NumPy images. Some sample data is show below.
#
# <img src='assets/processed_face_data.png' width=60% />
#
# > If you are working locally, you can download this data [by clicking here](https://s3.amazonaws.com/video.udacity-data.com/topher/2018/November/5be7eb6f_processed-celeba-small/processed-celeba-small.zip)
#
# This is a zip file that you'll need to extract in the home directory of this notebook for further loading and processing. After extracting the data, you should be left with a directory of data `processed_celeba_small/`

# %%
# can comment out after executing
# !unzip processed_celeba_small.zip
# Out:
# unzip:  cannot find or open processed_celeba_small.zip, processed_celeba_small.zip.zip or processed_celeba_small.zip.ZIP.

# %%
data_dir = 'processed_celeba_small/'

"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import pickle as pkl
import matplotlib.pyplot as plt
import numpy as np
import problem_unittests as tests
#import helper

# %matplotlib inline

# %% [markdown]
# ## Visualize the CelebA Data
#
# The [CelebA](http://mmlab.ie.cuhk.edu.hk/projects/CelebA.html) dataset contains over 200,000 celebrity images with annotations. Since you're going to be generating faces, you won't need the annotations, you'll only need the images. Note that these are color images with [3 color channels (RGB)](https://en.wikipedia.org/wiki/Channel_(digital_image)#RGB_Images) each.
#
# ### Pre-process and Load the Data
#
# Since the project's main focus is on building the GANs, we've done *some* of the pre-processing for you. Each of the CelebA images has been cropped to remove parts of the image that don't include a face, then resized down to 64x64x3 NumPy images. This *pre-processed* dataset is a smaller subset of the very large CelebA data.
#
# > There are a few other steps that you'll need to **transform** this data and create a **DataLoader**.
#
# #### Exercise: Complete the following `get_dataloader` function, such that it satisfies these requirements:
#
# * Your images should be square, Tensor images of size `image_size x image_size` in the x and y dimension.
# * Your function should return a DataLoader that shuffles and batches these Tensor images.
#
# #### ImageFolder
#
# To create a dataset given a directory of images, it's recommended that you use PyTorch's [ImageFolder](https://pytorch.org/docs/0.4.0/torchvision/datasets.html#imagefolder) wrapper, with a root directory `processed_celeba_small/` and data transformation passed in.

# %%
# necessary imports
import torch
import os
from torchvision import datasets
from torchvision import transforms
from torch.utils.data import DataLoader  # Import DataLoader

# %%
def get_dataloader(batch_size, image_size, data_dir='processed_celeba_small/', num_workers=0):
    """
    Batch the neural network data using DataLoader
    :param batch_size: The size of each batch; the number of images in a batch
    :param img_size: The square size of the image data (x, y)
    :param data_dir: Directory where image data is located
    :return: DataLoader with batched data
    """
    
    # TODO: Implement function and return a dataloader
    if not os.path.isdir(data_dir):
        raise FileNotFoundError(f"The directory {data_dir} does not exist.")
    # resize and normalize the images
    transform = transforms.Compose([transforms.Resize(image_size), # resize to 64x64
                                    transforms.ToTensor()])

    # define datasets using ImageFolder
    dataset = datasets.ImageFolder(data_dir, transform)
    
    # create and return DataLoaders
    data_loader = DataLoader(dataset=dataset, batch_size=batch_size, shuffle=True, num_workers=num_workers)
    
    return data_loader

# %% [markdown]
# ## Create a DataLoader
#
# #### Exercise: Create a DataLoader `celeba_train_loader` with appropriate hyperparameters.
#
# Call the above function and create a dataloader to view images.
# * You can decide on any reasonable `batch_size` parameter
# * Your `image_size` **must be** `32`. Resizing the data to a smaller size will make for faster training, while still creating convincing images of faces!

# %% [markdown]
# Next, you can view some images! You should see square images of somewhat-centered faces.
#
# Note: You'll need to convert the Tensor images into a NumPy type and transpose the dimensions to correctly display an image, suggested `imshow` code is below, but it may not be perfect.

# %%
# Define function hyperparameters
batch_size = 128
img_size = 32

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
# Call your function and get a dataloader
data_dir = '/home/daniel-diegel/deep-learning-v2-pytorch-master/project-face-generation/processed-celeba-small/processed_celeba_small'
celeba_train_loader = get_dataloader(batch_size, img_size, data_dir)

# helper display function
def imshow(img):
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
# Assuming 'images' is a batch of images from your DataLoader
images, labels = next(iter(celeba_train_loader))

fig = plt.figure(figsize=(20, 4))
plot_size = 20
for idx in np.arange(plot_size):
    ax = fig.add_subplot(2, plot_size // 2, idx + 1, xticks=[], yticks=[])
    imshow(images[idx])

plt.show()

# %% [markdown]
# #### Exercise: Pre-process your image data and scale it to a pixel range of -1 to 1
#
# You need to do a bit of pre-processing; you know that the output of a `tanh` activated generator will contain pixel values in a range from -1 to 1, and so, we need to rescale our training images to a range of -1 to 1. (Right now, they are in a range from 0-1.)

# %%
# TODO: Complete the scale function
def scale(x, feature_range=(-1, 1)):
    ''' Scale takes in an image x and returns that image, scaled
       with a feature_range of pixel values from -1 to 1. 
       This function assumes that the input x is already scaled from 0-1.'''
    # assume x is scaled to (0, 1)
    # scale to feature_range and return scaled x
    min, max = feature_range
    x = x * (max - min) + min
    
    return x

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
# check scaled range
# should be close to -1 to 1
img = images[0]
scaled_img = scale(img)

print('Min: ', scaled_img.min())
print('Max: ', scaled_img.max())
# Out:
# Min:  tensor(-0.9529)
# Max:  tensor(0.5373)

# %% [markdown]
# ---
# # Define the Model
#
# A GAN is comprised of two adversarial networks, a discriminator and a generator.
#
# ## Discriminator
#
# Your first task will be to define the discriminator. This is a convolutional classifier like you've built before, only without any maxpooling layers. To deal with this complex data, it's suggested you use a deep network with **normalization**. You are also allowed to create any helper functions that may be useful.
#
# #### Exercise: Complete the Discriminator class
# * The inputs to the discriminator are 32x32x3 tensor images
# * The output should be a single value that will indicate whether a given image is real or fake

# %%
import torch.nn as nn
import torch.nn.functional as F

# helper conv function
def conv(in_channels, out_channels, kernel_size, stride=2, padding=1, batch_norm=True):
    """Creates a convolutional layer, with optional batch normalization.
    """
    layers = []
    conv_layer = nn.Conv2d(in_channels, out_channels, 
                           kernel_size, stride, padding, bias=False)
    
    # append conv layer
    layers.append(conv_layer)

    if batch_norm:
        # append batchnorm layer
        layers.append(nn.BatchNorm2d(out_channels))
     
    # using Sequential container
    return nn.Sequential(*layers)

# %%
class Discriminator(nn.Module):

    def __init__(self, conv_dim=32):
        super(Discriminator, self).__init__()

        # complete init function
        self.conv_dim = conv_dim

        # 32x32 input
        self.conv1 = conv(3, conv_dim, 4, batch_norm=False) # first layer, no batch_norm
        # 16x16 out
        self.conv2 = conv(conv_dim, conv_dim*2, 4)
        # 8x8 out
        self.conv3 = conv(conv_dim*2, conv_dim*4, 4)
        # 4x4 out
        
        # final, fully-connected layer
        self.fc = nn.Linear(conv_dim*4*4*4, 1)

    def forward(self, x):
        # all hidden layers + leaky relu activation
        out = F.leaky_relu(self.conv1(x), 0.2)
        out = F.leaky_relu(self.conv2(out), 0.2)
        out = F.leaky_relu(self.conv3(out), 0.2)
        
        # flatten
        out = out.view(-1, self.conv_dim*4*4*4)
        
        # final output layer
        out = self.fc(out)        
        return out


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_discriminator(Discriminator)
# Out:
# Tests Passed

# %% [markdown]
# ## Generator
#
# The generator should upsample an input and generate a *new* image of the same size as our training data `32x32x3`. This should be mostly transpose convolutional layers with normalization applied to the outputs.
#
# #### Exercise: Complete the Generator class
# * The inputs to the generator are vectors of some length `z_size`
# * The output should be a image of shape `32x32x3`

# %%
# helper deconv function
def deconv(in_channels, out_channels, kernel_size, stride=2, padding=1, batch_norm=True):
    """Creates a transposed-convolutional layer, with optional batch normalization.
    """
    # create a sequence of transpose + optional batch norm layers
    layers = []
    transpose_conv_layer = nn.ConvTranspose2d(in_channels, out_channels, 
                                              kernel_size, stride, padding, bias=False)
    # append transpose convolutional layer
    layers.append(transpose_conv_layer)
    
    if batch_norm:
        # append batchnorm layer
        layers.append(nn.BatchNorm2d(out_channels))
        
    return nn.Sequential(*layers)

    
class Generator(nn.Module):
    
    def __init__(self, z_size, conv_dim=32):
        super(Generator, self).__init__()

        # complete init function
        
        self.conv_dim = conv_dim
        
        # first, fully-connected layer
        self.fc = nn.Linear(z_size, conv_dim*4*4*4)

        # transpose conv layers
        self.t_conv1 = deconv(conv_dim*4, conv_dim*2, 4)
        self.t_conv2 = deconv(conv_dim*2, conv_dim, 4)
        self.t_conv3 = deconv(conv_dim, 3, 4, batch_norm=False)
        

    def forward(self, x):
        # fully-connected + reshape 
        out = self.fc(x)
        out = out.view(-1, self.conv_dim*4, 4, 4) # (batch_size, depth, 4, 4)
        
        out = F.leaky_relu(self.t_conv1(out), 0.2)
        out = F.leaky_relu(self.t_conv2(out), 0.2)
        # last layer + tanh activation
        out = self.t_conv3(out)
        out = F.tanh(out)

        
        return out
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_generator(Generator)
# Out:
# Tests Passed

# %% [markdown]
# ## Initialize the weights of your networks
#
# To help your models converge, you should initialize the weights of the convolutional and linear layers in your model. From reading the [original DCGAN paper](https://arxiv.org/pdf/1511.06434.pdf), they say:
# > All weights were initialized from a zero-centered Normal distribution with standard deviation 0.02.
#
# So, your next task will be to define a weight initialization function that does just this!
#
# You can refer back to the lesson on weight initialization or even consult existing model code, such as that from [the `networks.py` file in CycleGAN Github repository](https://github.com/junyanz/pytorch-CycleGAN-and-pix2pix/blob/master/models/networks.py) to help you complete this function.
#
# #### Exercise: Complete the weight initialization function
#
# * This should initialize only **convolutional** and **linear** layers
# * Initialize the weights to a normal distribution, centered around 0, with a standard deviation of 0.02.
# * The bias terms, if they exist, may be left alone or set to 0.

# %%
def weights_init_normal(m):
    """
    Applies initial weights to certain layers in a model .
    The weights are taken from a normal distribution 
    with mean = 0, std dev = 0.02.
    :param m: A module or layer in a network    
    """
    # classname will be something like:
    # `Conv`, `BatchNorm2d`, `Linear`, etc.
    classname = m.__class__.__name__
    
    # TODO: Apply initial weights to convolutional and linear layers
    if classname.find('Conv') != -1:
        nn.init.normal_(m.weight.data, 0.0, 0.02)
    elif classname.find('BatchNorm') != -1:
        nn.init.normal_(m.weight.data, 1.0, 0.02)
        nn.init.constant_(m.bias.data, 0)
    elif classname.find('Linear') != -1:
        nn.init.normal_(m.weight.data, 0.0, 0.02)
        nn.init.constant_(m.bias.data, 0)

# %% [markdown]
# ## Build complete network
#
# Define your models' hyperparameters and instantiate the discriminator and generator from the classes defined above. Make sure you've passed in the correct input arguments.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
def build_network(d_conv_dim, g_conv_dim, z_size):
    # define discriminator and generator
    D = Discriminator(d_conv_dim)
    G = Generator(z_size=z_size, conv_dim=g_conv_dim)

    # initialize model weights
    D.apply(weights_init_normal)
    G.apply(weights_init_normal)

    print(D)
    print()
    print(G)
    
    return D, G

# %% [markdown]
# #### Exercise: Define model hyperparameters

# %%
# Define model hyperparams
d_conv_dim = 32
g_conv_dim = 48
z_size = 120

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
D, G = build_network(d_conv_dim, g_conv_dim, z_size)
# Out:
# Discriminator(
#   (conv1): Sequential(
#     (0): Conv2d(3, 32, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   )
#   (conv2): Sequential(
#     (0): Conv2d(32, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (conv3): Sequential(
#     (0): Conv2d(64, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (fc): Linear(in_features=2048, out_features=1, bias=True)
# )
#
# Generator(
#   (fc): Linear(in_features=120, out_features=3072, bias=True)
#   (t_conv1): Sequential(
#     (0): ConvTranspose2d(192, 96, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (t_conv2): Sequential(
#     (0): ConvTranspose2d(96, 48, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (t_conv3): Sequential(
#     (0): ConvTranspose2d(48, 3, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   )
# )

# %% [markdown]
# ### Training on GPU
#
# Check if you can train on GPU. Here, we'll set this as a boolean variable `train_on_gpu`. Later, you'll be responsible for making sure that
# >* Models,
# * Model inputs, and
# * Loss function arguments
#
# Are moved to GPU, where appropriate.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import torch

# Check for a GPU
train_on_gpu = torch.cuda.is_available()
if not train_on_gpu:
    print('No GPU found. Please use a GPU to train your neural network.')
else:
    print('Training on GPU!')

# Check if CUDA is available
print("CUDA available:", torch.cuda.is_available())

# Print the CUDA version
print("CUDA version:", torch.version.cuda)

# Print the current GPU device
if torch.cuda.is_available():
    print("Current GPU device:", torch.cuda.current_device())
    print("GPU device name:", torch.cuda.get_device_name(torch.cuda.current_device()))
# Out:
# Training on GPU!
# CUDA available: True
# CUDA version: 12.4
# Current GPU device: 0
# GPU device name: NVIDIA GeForce RTX 3080 Ti Laptop GPU

# %% [markdown]
# ---
# ## Discriminator and Generator Losses
#
# Now we need to calculate the losses for both types of adversarial networks.
#
# ### Discriminator Losses
#
# > * For the discriminator, the total loss is the sum of the losses for real and fake images, `d_loss = d_real_loss + d_fake_loss`.
# * Remember that we want the discriminator to output 1 for real images and 0 for fake images, so we need to set up the losses to reflect that.
#
#
# ### Generator Loss
#
# The generator loss will look similar only with flipped labels. The generator's goal is to get the discriminator to *think* its generated images are *real*.
#
# #### Exercise: Complete real and fake loss functions
#
# **You may choose to use either cross entropy or a least squares error loss to complete the following `real_loss` and `fake_loss` functions.**

# %%
def real_loss(D_out, smooth=False):
    batch_size = D_out.size(0)
    # label smoothing
    if smooth:
        # smooth, real labels = 0.9
        labels = torch.ones(batch_size)*0.9
    else:
        labels = torch.ones(batch_size) # real labels = 1
    # move labels to GPU if available     
    if train_on_gpu:
        labels = labels.cuda()
    # binary cross entropy with logits loss
    criterion = nn.BCEWithLogitsLoss()
    # calculate loss
    loss = criterion(D_out.squeeze(), labels)
    return loss

def fake_loss(D_out):
    batch_size = D_out.size(0)
    labels = torch.zeros(batch_size) # fake labels = 0
    if train_on_gpu:
        labels = labels.cuda()
    criterion = nn.BCEWithLogitsLoss()
    # calculate loss
    loss = criterion(D_out.squeeze(), labels)
    return loss

# %% [markdown]
# ## Optimizers
#
# #### Exercise: Define optimizers for your Discriminator (D) and Generator (G)
#
# Define optimizers for your models with appropriate hyperparameters.

# %%
import torch.optim as optim

# Create optimizers for the discriminator D and generator G
# params
lr = 0.0001
beta1=0.5
beta2=0.999 # default value

# Create optimizers for the discriminator and generator
d_optimizer = optim.Adam(D.parameters(), lr, [beta1, beta2])
g_optimizer = optim.Adam(G.parameters(), lr, [beta1, beta2])

# %% [markdown]
# ---
# ## Training
#
# Training will involve alternating between training the discriminator and the generator. You'll use your functions `real_loss` and `fake_loss` to help you calculate the discriminator losses.
#
# * You should train the discriminator by alternating on real and fake images
# * Then the generator, which tries to trick the discriminator and should have an opposing loss function
#
#
# #### Saving Samples
#
# You've been given some code to print out some loss statistics and save some generated "fake" samples.

# %% [markdown]
# #### Exercise: Complete the training function
#
# Keep in mind that, if you've moved your models to GPU, you'll also have to move any model inputs to GPU.

# %%
def train(D, G, n_epochs, print_every=50):
    '''Trains adversarial networks for some number of epochs
       param, D: the discriminator network
       param, G: the generator network
       param, n_epochs: number of epochs to train for
       param, print_every: when to print and record the models' losses
       return: D and G losses'''
    
    # move models to GPU
    if train_on_gpu:
        D.cuda()
        G.cuda()

    # keep track of loss and generated, "fake" samples
    samples = []
    losses = []

    # Get some fixed data for sampling. These are images that are held
    # constant throughout training, and allow us to inspect the model's performance
    sample_size=16
    fixed_z = np.random.uniform(-1, 1, size=(sample_size, z_size))
    fixed_z = torch.from_numpy(fixed_z).float()
    # move z to GPU if available
    if train_on_gpu:
        fixed_z = fixed_z.cuda()

    # epoch training loop
    for epoch in range(n_epochs):

        # batch training loop
        for batch_i, (real_images, _) in enumerate(celeba_train_loader):

            batch_size = real_images.size(0)
            real_images = scale(real_images)

            # ===============================================
            #         YOUR CODE HERE: TRAIN THE NETWORKS
            # ===============================================
            
           # ============================================
        #            TRAIN THE DISCRIMINATOR
        # ============================================
            
            d_optimizer.zero_grad()
            
            # 1. Train with real images
    
            # Compute the discriminator losses on real images 
            if train_on_gpu:
                real_images = real_images.cuda()
            
            D_real = D(real_images)
            d_real_loss = real_loss(D_real)
            
            # 2. Train with fake images
            
            # Generate fake images
            z = np.random.uniform(-1, 1, size=(batch_size, z_size))
            z = torch.from_numpy(z).float()
            # move x to GPU, if available
            if train_on_gpu:
                z = z.cuda()
            fake_images = G(z)
        
            # Compute the discriminator losses on fake images            
            D_fake = D(fake_images)
            d_fake_loss = fake_loss(D_fake)
            
            # add up loss and perform backprop
            d_loss = d_real_loss + d_fake_loss
            d_loss.backward()
            d_optimizer.step()
            
            
            # =========================================
            #            TRAIN THE GENERATOR
            # =========================================
            g_optimizer.zero_grad()
            
            # 1. Train with fake images and flipped labels
            
            # Generate fake images
            z = np.random.uniform(-1, 1, size=(batch_size, z_size))
            z = torch.from_numpy(z).float()
            if train_on_gpu:
                z = z.cuda()
            fake_images = G(z)
            
            # Compute the discriminator losses on fake images 
            # using flipped labels!
            D_fake = D(fake_images)
            g_loss = real_loss(D_fake) # use real loss to flip labels
            
            # perform backprBuild complete networkop
            g_loss.backward()
            g_optimizer.step()

            
            
            # ===============================================
            #              END OF YOUR CODE
            # ===============================================

            # Print some loss stats
            if batch_i % print_every == 0:
                # append discriminator loss and generator loss
                losses.append((d_loss.item(), g_loss.item()))
                # print discriminator and generator loss
                print('Epoch [{:5d}/{:5d}] | d_loss: {:6.4f} | g_loss: {:6.4f}'.format(
                        epoch+1, n_epochs, d_loss.item(), g_loss.item()))


        ## AFTER EACH EPOCH##    
        # this code assumes your generator is named G, feel free to change the name
        # generate and save sample, fake images
        G.eval() # for generating samples
        with torch.no_grad():
            samples_z = G(fixed_z)
            samples_z = samples_z.detach().cpu()
            samples.append(samples_z)
        G.train() # back to training mode

    # Save training generator samples
    #with open('train_samples_".pkl', 'wb') as f:
        #pkl.dump(samples, f)
    
    # finally return losses
    return losses

# %% [markdown]
# Set your number of training epochs and train your GAN!

# %%
# set number of epochs 
n_epochs = 35


"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# call training function
losses = train(D, G, n_epochs=n_epochs)
# Out:
# Epoch [    1/   35] | d_loss: 1.2385 | g_loss: 1.1911
# Epoch [    1/   35] | d_loss: 0.2770 | g_loss: 2.2553
# Epoch [    1/   35] | d_loss: 0.2136 | g_loss: 2.7547
# Epoch [    1/   35] | d_loss: 0.4340 | g_loss: 2.2141
# Epoch [    1/   35] | d_loss: 0.4211 | g_loss: 2.0575
# Epoch [    1/   35] | d_loss: 0.9305 | g_loss: 2.3419
# Epoch [    1/   35] | d_loss: 0.7801 | g_loss: 2.1542
# Epoch [    1/   35] | d_loss: 0.5018 | g_loss: 2.2101
# Epoch [    1/   35] | d_loss: 0.7551 | g_loss: 0.9794
# Epoch [    1/   35] | d_loss: 0.6803 | g_loss: 1.3153
# Epoch [    1/   35] | d_loss: 0.6899 | g_loss: 1.1558
# Epoch [    1/   35] | d_loss: 0.7102 | g_loss: 2.1049
# Epoch [    1/   35] | d_loss: 0.8976 | g_loss: 1.1117
# Epoch [    1/   35] | d_loss: 0.7981 | g_loss: 1.2500
# Epoch [    1/   35] | d_loss: 1.0767 | g_loss: 0.9568
# Epoch [    2/   35] | d_loss: 1.0099 | g_loss: 1.0989
# Epoch [    2/   35] | d_loss: 0.9009 | g_loss: 1.5076
# Epoch [    2/   35] | d_loss: 1.0820 | g_loss: 0.9975
# Epoch [    2/   35] | d_loss: 1.2359 | g_loss: 1.6958
# Epoch [    2/   35] | d_loss: 1.2287 | g_loss: 0.6104
# Epoch [    2/   35] | d_loss: 1.0376 | g_loss: 0.9871
# Epoch [    2/   35] | d_loss: 1.1329 | g_loss: 1.0973
# Epoch [    2/   35] | d_loss: 1.0625 | g_loss: 0.9487
# Epoch [    2/   35] | d_loss: 1.1661 | g_loss: 1.6516
# Epoch [    2/   35] | d_loss: 1.1222 | g_loss: 0.9781
# Epoch [    2/   35] | d_loss: 0.8119 | g_loss: 2.0117
# Epoch [    2/   35] | d_loss: 1.3637 | g_loss: 0.9121
# Epoch [    2/   35] | d_loss: 1.1447 | g_loss: 0.7783
# Epoch [    2/   35] | d_loss: 1.0184 | g_loss: 1.1470
# Epoch [    2/   35] | d_loss: 1.1386 | g_loss: 0.9639
# Epoch [    3/   35] | d_loss: 1.1770 | g_loss: 1.2205
# Epoch [    3/   35] | d_loss: 1.1267 | g_loss: 1.1801
# Epoch [    3/   35] | d_loss: 1.1559 | g_loss: 0.9465
# Epoch [    3/   35] | d_loss: 1.2132 | g_loss: 0.9512
# Epoch [    3/   35] | d_loss: 0.8045 | g_loss: 1.1349
# Epoch [    3/   35] | d_loss: 1.1307 | g_loss: 0.9487
# Epoch [    3/   35] | d_loss: 0.9985 | g_loss: 0.8015
# Epoch [    3/   35] | d_loss: 1.2211 | g_loss: 1.0791
# Epoch [    3/   35] | d_loss: 1.1648 | g_loss: 1.2459
# Epoch [    3/   35] | d_loss: 1.4218 | g_loss: 1.2702
# Epoch [    3/   35] | d_loss: 1.2274 | g_loss: 1.7444
# Epoch [    3/   35] | d_loss: 0.7509 | g_loss: 1.5933
# Epoch [    3/   35] | d_loss: 1.0491 | g_loss: 1.1539
# Epoch [    3/   35] | d_loss: 0.7704 | g_loss: 1.4921
# Epoch [    3/   35] | d_loss: 1.0387 | g_loss: 0.7436
# Epoch [    4/   35] | d_loss: 0.8038 | g_loss: 1.4839
# Epoch [    4/   35] | d_loss: 1.0072 | g_loss: 0.9825
# Epoch [    4/   35] | d_loss: 0.6997 | g_loss: 1.4493
# Epoch [    4/   35] | d_loss: 0.8416 | g_loss: 1.9469
# Epoch [    4/   35] | d_loss: 0.9055 | g_loss: 0.8126
# Epoch [    4/   35] | d_loss: 0.9581 | g_loss: 1.3318
# Epoch [    4/   35] | d_loss: 0.8684 | g_loss: 1.4386
# Epoch [    4/   35] | d_loss: 1.0154 | g_loss: 1.3298
# Epoch [    4/   35] | d_loss: 0.9758 | g_loss: 1.3089
# Epoch [    4/   35] | d_loss: 0.8863 | g_loss: 1.1419
# Epoch [    4/   35] | d_loss: 0.9230 | g_loss: 0.9188
# Epoch [    4/   35] | d_loss: 1.1045 | g_loss: 1.0512
# Epoch [    4/   35] | d_loss: 0.8994 | g_loss: 1.0890
# Epoch [    4/   35] | d_loss: 1.0647 | g_loss: 1.1381
# Epoch [    4/   35] | d_loss: 1.0795 | g_loss: 0.5719
# Epoch [    5/   35] | d_loss: 0.9834 | g_loss: 1.1871
# Epoch [    5/   35] | d_loss: 0.8196 | g_loss: 1.2891
# Epoch [    5/   35] | d_loss: 0.9593 | g_loss: 1.1593
# Epoch [    5/   35] | d_loss: 0.8354 | g_loss: 1.4481
# Epoch [    5/   35] | d_loss: 1.0194 | g_loss: 1.2042
# Epoch [    5/   35] | d_loss: 1.3705 | g_loss: 0.6060
# Epoch [    5/   35] | d_loss: 1.2699 | g_loss: 0.8303
# Epoch [    5/   35] | d_loss: 1.2338 | g_loss: 1.1501
# Epoch [    5/   35] | d_loss: 1.0920 | g_loss: 1.2138
# Epoch [    5/   35] | d_loss: 1.3392 | g_loss: 0.6622
# Epoch [    5/   35] | d_loss: 1.0560 | g_loss: 1.0028
# Epoch [    5/   35] | d_loss: 1.0210 | g_loss: 1.3920
# Epoch [    5/   35] | d_loss: 1.0902 | g_loss: 1.3112
# Epoch [    5/   35] | d_loss: 1.0568 | g_loss: 1.5180
# Epoch [    5/   35] | d_loss: 1.0845 | g_loss: 1.1206
# Epoch [    6/   35] | d_loss: 1.0716 | g_loss: 0.9809
# Epoch [    6/   35] | d_loss: 1.1002 | g_loss: 1.1326
# Epoch [    6/   35] | d_loss: 1.1344 | g_loss: 1.0953
# Epoch [    6/   35] | d_loss: 1.1279 | g_loss: 1.2502
# Epoch [    6/   35] | d_loss: 0.9376 | g_loss: 1.6618
# Epoch [    6/   35] | d_loss: 0.9373 | g_loss: 1.2648
# Epoch [    6/   35] | d_loss: 1.0051 | g_loss: 1.3517
# Epoch [    6/   35] | d_loss: 1.0622 | g_loss: 1.2634
# Epoch [    6/   35] | d_loss: 1.1324 | g_loss: 1.3018
# Epoch [    6/   35] | d_loss: 1.1087 | g_loss: 1.1373
# Epoch [    6/   35] | d_loss: 0.9640 | g_loss: 1.2283
# Epoch [    6/   35] | d_loss: 0.8726 | g_loss: 0.7949
# Epoch [    6/   35] | d_loss: 1.0923 | g_loss: 1.0426
# Epoch [    6/   35] | d_loss: 0.9418 | g_loss: 1.5608
# Epoch [    6/   35] | d_loss: 0.8424 | g_loss: 1.3726
# Epoch [    7/   35] | d_loss: 1.1166 | g_loss: 1.1862
# Epoch [    7/   35] | d_loss: 1.2575 | g_loss: 0.7831
# Epoch [    7/   35] | d_loss: 0.8703 | g_loss: 1.0126
# Epoch [    7/   35] | d_loss: 0.9338 | g_loss: 1.1432
# Epoch [    7/   35] | d_loss: 0.9503 | g_loss: 0.9833
# Epoch [    7/   35] | d_loss: 1.3960 | g_loss: 0.6018
# Epoch [    7/   35] | d_loss: 1.0931 | g_loss: 0.9828
# Epoch [    7/   35] | d_loss: 1.0992 | g_loss: 1.2072
# Epoch [    7/   35] | d_loss: 1.0822 | g_loss: 0.7633
# Epoch [    7/   35] | d_loss: 1.0069 | g_loss: 1.0888
# Epoch [    7/   35] | d_loss: 1.1530 | g_loss: 1.5479
# Epoch [    7/   35] | d_loss: 0.9798 | g_loss: 2.0673
# Epoch [    7/   35] | d_loss: 1.2564 | g_loss: 1.2288
# Epoch [    7/   35] | d_loss: 1.0442 | g_loss: 1.4476
# Epoch [    7/   35] | d_loss: 0.8528 | g_loss: 1.4642
# Epoch [    8/   35] | d_loss: 0.9681 | g_loss: 1.7796
# Epoch [    8/   35] | d_loss: 1.3217 | g_loss: 0.7418
# Epoch [    8/   35] | d_loss: 1.0214 | g_loss: 1.7976
# Epoch [    8/   35] | d_loss: 0.9115 | g_loss: 1.1320
# Epoch [    8/   35] | d_loss: 0.8718 | g_loss: 1.8070
# Epoch [    8/   35] | d_loss: 0.9696 | g_loss: 1.1691
# Epoch [    8/   35] | d_loss: 1.0574 | g_loss: 1.9043
# Epoch [    8/   35] | d_loss: 0.9183 | g_loss: 1.0809
# Epoch [    8/   35] | d_loss: 1.0924 | g_loss: 0.8291
# Epoch [    8/   35] | d_loss: 0.9796 | g_loss: 1.0856
# Epoch [    8/   35] | d_loss: 0.8934 | g_loss: 1.4125
# Epoch [    8/   35] | d_loss: 1.0472 | g_loss: 0.9840
# Epoch [    8/   35] | d_loss: 0.9211 | g_loss: 1.1960
# Epoch [    8/   35] | d_loss: 0.9295 | g_loss: 1.3799
# Epoch [    8/   35] | d_loss: 0.8544 | g_loss: 0.8554
# Epoch [    9/   35] | d_loss: 0.9738 | g_loss: 1.5097
# Epoch [    9/   35] | d_loss: 1.2376 | g_loss: 1.1786
# Epoch [    9/   35] | d_loss: 0.8239 | g_loss: 1.7444
# Epoch [    9/   35] | d_loss: 1.1657 | g_loss: 2.2681
# Epoch [    9/   35] | d_loss: 1.0117 | g_loss: 1.5695
# Epoch [    9/   35] | d_loss: 1.0872 | g_loss: 1.1653
# Epoch [    9/   35] | d_loss: 0.9323 | g_loss: 1.0493
# Epoch [    9/   35] | d_loss: 0.8690 | g_loss: 1.3211
# Epoch [    9/   35] | d_loss: 1.1293 | g_loss: 1.3684
# Epoch [    9/   35] | d_loss: 1.1014 | g_loss: 1.3451
# Epoch [    9/   35] | d_loss: 0.7069 | g_loss: 1.2945
# Epoch [    9/   35] | d_loss: 0.8742 | g_loss: 1.2449
# Epoch [    9/   35] | d_loss: 1.1149 | g_loss: 0.7072
# Epoch [    9/   35] | d_loss: 0.8391 | g_loss: 1.6403
# Epoch [    9/   35] | d_loss: 0.9401 | g_loss: 0.8314
# Epoch [   10/   35] | d_loss: 0.9124 | g_loss: 1.0315
# Epoch [   10/   35] | d_loss: 0.8320 | g_loss: 1.3631
# Epoch [   10/   35] | d_loss: 1.0185 | g_loss: 1.3532
# Epoch [   10/   35] | d_loss: 0.9460 | g_loss: 1.0901
# Epoch [   10/   35] | d_loss: 0.7525 | g_loss: 1.8187
# Epoch [   10/   35] | d_loss: 1.1938 | g_loss: 1.1378
# Epoch [   10/   35] | d_loss: 0.9755 | g_loss: 0.7316
# Epoch [   10/   35] | d_loss: 1.1378 | g_loss: 1.0141
# Epoch [   10/   35] | d_loss: 0.7811 | g_loss: 1.6825
# Epoch [   10/   35] | d_loss: 0.9567 | g_loss: 1.6472
# Epoch [   10/   35] | d_loss: 1.3625 | g_loss: 0.8587
# Epoch [   10/   35] | d_loss: 1.0093 | g_loss: 0.7383
# Epoch [   10/   35] | d_loss: 0.9776 | g_loss: 1.3882
# Epoch [   10/   35] | d_loss: 1.0442 | g_loss: 0.7232
# Epoch [   10/   35] | d_loss: 0.8083 | g_loss: 1.2848
# Epoch [   11/   35] | d_loss: 0.8204 | g_loss: 1.5744
# Epoch [   11/   35] | d_loss: 0.9820 | g_loss: 1.8343
# Epoch [   11/   35] | d_loss: 1.1262 | g_loss: 1.4316
# Epoch [   11/   35] | d_loss: 1.0994 | g_loss: 1.2123
# Epoch [   11/   35] | d_loss: 1.1625 | g_loss: 1.5647
# Epoch [   11/   35] | d_loss: 0.9256 | g_loss: 1.4093
# Epoch [   11/   35] | d_loss: 0.8610 | g_loss: 1.2020
# Epoch [   11/   35] | d_loss: 0.9110 | g_loss: 1.2074
# Epoch [   11/   35] | d_loss: 0.7883 | g_loss: 1.7865
# Epoch [   11/   35] | d_loss: 0.9401 | g_loss: 1.4343
# Epoch [   11/   35] | d_loss: 0.8523 | g_loss: 1.1566
# Epoch [   11/   35] | d_loss: 0.8816 | g_loss: 1.3339
# Epoch [   11/   35] | d_loss: 1.3172 | g_loss: 1.0026
# Epoch [   11/   35] | d_loss: 0.9570 | g_loss: 1.0274
# Epoch [   11/   35] | d_loss: 0.9611 | g_loss: 1.0104
# Epoch [   12/   35] | d_loss: 0.9273 | g_loss: 1.1712
# Epoch [   12/   35] | d_loss: 1.1368 | g_loss: 0.8391
# Epoch [   12/   35] | d_loss: 0.8633 | g_loss: 0.8982
# Epoch [   12/   35] | d_loss: 0.9750 | g_loss: 0.7450
# Epoch [   12/   35] | d_loss: 0.9241 | g_loss: 1.7548
# Epoch [   12/   35] | d_loss: 0.9403 | g_loss: 1.1265
# Epoch [   12/   35] | d_loss: 0.7523 | g_loss: 1.2795
# Epoch [   12/   35] | d_loss: 0.7363 | g_loss: 1.4068
# Epoch [   12/   35] | d_loss: 0.9905 | g_loss: 1.5842
# Epoch [   12/   35] | d_loss: 0.9512 | g_loss: 1.6519
# Epoch [   12/   35] | d_loss: 0.9893 | g_loss: 1.4884
# Epoch [   12/   35] | d_loss: 0.9288 | g_loss: 0.8836
# Epoch [   12/   35] | d_loss: 1.1448 | g_loss: 2.5484
# Epoch [   12/   35] | d_loss: 0.8461 | g_loss: 1.2915
# Epoch [   12/   35] | d_loss: 0.8889 | g_loss: 0.9636
# Epoch [   13/   35] | d_loss: 0.9668 | g_loss: 1.1428
# Epoch [   13/   35] | d_loss: 0.8206 | g_loss: 1.1501
# Epoch [   13/   35] | d_loss: 0.7350 | g_loss: 1.1117
# Epoch [   13/   35] | d_loss: 0.7617 | g_loss: 1.2691
# Epoch [   13/   35] | d_loss: 0.7507 | g_loss: 1.7446
# Epoch [   13/   35] | d_loss: 0.9599 | g_loss: 1.4082
# Epoch [   13/   35] | d_loss: 0.4370 | g_loss: 2.8122
# Epoch [   13/   35] | d_loss: 0.9452 | g_loss: 1.4886
# Epoch [   13/   35] | d_loss: 0.8528 | g_loss: 1.3381
# Epoch [   13/   35] | d_loss: 0.8128 | g_loss: 0.9654
# Epoch [   13/   35] | d_loss: 0.7372 | g_loss: 1.2738
# Epoch [   13/   35] | d_loss: 0.7747 | g_loss: 1.4992
# Epoch [   13/   35] | d_loss: 1.0002 | g_loss: 2.2179
# Epoch [   13/   35] | d_loss: 1.1644 | g_loss: 0.7046
# Epoch [   13/   35] | d_loss: 1.0096 | g_loss: 0.8519
# Epoch [   14/   35] | d_loss: 1.0035 | g_loss: 2.1785
# Epoch [   14/   35] | d_loss: 0.7436 | g_loss: 1.4643
# Epoch [   14/   35] | d_loss: 0.7679 | g_loss: 1.6562
# Epoch [   14/   35] | d_loss: 0.8383 | g_loss: 1.2271
# Epoch [   14/   35] | d_loss: 0.9607 | g_loss: 1.2014
# Epoch [   14/   35] | d_loss: 0.9238 | g_loss: 1.1545
# Epoch [   14/   35] | d_loss: 0.9450 | g_loss: 1.4165
# Epoch [   14/   35] | d_loss: 0.8944 | g_loss: 1.1826
# Epoch [   14/   35] | d_loss: 0.8514 | g_loss: 1.3480
# Epoch [   14/   35] | d_loss: 0.8904 | g_loss: 1.0274
# Epoch [   14/   35] | d_loss: 1.0694 | g_loss: 1.4639
# Epoch [   14/   35] | d_loss: 0.7040 | g_loss: 1.2239
# Epoch [   14/   35] | d_loss: 0.9156 | g_loss: 1.2741
# Epoch [   14/   35] | d_loss: 0.7010 | g_loss: 1.9147
# Epoch [   14/   35] | d_loss: 0.8597 | g_loss: 1.3424
# Epoch [   15/   35] | d_loss: 0.8361 | g_loss: 1.1002
# Epoch [   15/   35] | d_loss: 1.0912 | g_loss: 1.2114
# Epoch [   15/   35] | d_loss: 0.8297 | g_loss: 1.2035
# Epoch [   15/   35] | d_loss: 1.1833 | g_loss: 0.9629
# Epoch [   15/   35] | d_loss: 0.8890 | g_loss: 1.0843
# Epoch [   15/   35] | d_loss: 0.6687 | g_loss: 1.4290
# Epoch [   15/   35] | d_loss: 0.7551 | g_loss: 0.8316
# Epoch [   15/   35] | d_loss: 0.8311 | g_loss: 1.1880
# Epoch [   15/   35] | d_loss: 1.0758 | g_loss: 0.9881
# Epoch [   15/   35] | d_loss: 0.9311 | g_loss: 1.3324
# Epoch [   15/   35] | d_loss: 0.7609 | g_loss: 1.3181
# Epoch [   15/   35] | d_loss: 0.7811 | g_loss: 1.5497
# Epoch [   15/   35] | d_loss: 0.7957 | g_loss: 1.9815
# Epoch [   15/   35] | d_loss: 0.8616 | g_loss: 1.8717
# Epoch [   15/   35] | d_loss: 0.8004 | g_loss: 1.7823
# Epoch [   16/   35] | d_loss: 0.9635 | g_loss: 1.6601
# Epoch [   16/   35] | d_loss: 0.7872 | g_loss: 1.7836
# Epoch [   16/   35] | d_loss: 1.1193 | g_loss: 2.4309
# Epoch [   16/   35] | d_loss: 1.0093 | g_loss: 1.7641
# Epoch [   16/   35] | d_loss: 1.7399 | g_loss: 0.0549
# Epoch [   16/   35] | d_loss: 0.7830 | g_loss: 1.4129
# Epoch [   16/   35] | d_loss: 0.8729 | g_loss: 1.5805
# Epoch [   16/   35] | d_loss: 0.7436 | g_loss: 1.6079
# Epoch [   16/   35] | d_loss: 0.8753 | g_loss: 1.1382
# Epoch [   16/   35] | d_loss: 1.0249 | g_loss: 1.3779
# Epoch [   16/   35] | d_loss: 0.8726 | g_loss: 1.6600
# Epoch [   16/   35] | d_loss: 0.7710 | g_loss: 1.5660
# Epoch [   16/   35] | d_loss: 1.4556 | g_loss: 0.2722
# Epoch [   16/   35] | d_loss: 0.7363 | g_loss: 1.5444
# Epoch [   16/   35] | d_loss: 0.6886 | g_loss: 1.2935
# Epoch [   17/   35] | d_loss: 1.0013 | g_loss: 1.4011
# Epoch [   17/   35] | d_loss: 0.6562 | g_loss: 1.5237
# Epoch [   17/   35] | d_loss: 0.7440 | g_loss: 1.6937
# Epoch [   17/   35] | d_loss: 0.7765 | g_loss: 2.2149
# Epoch [   17/   35] | d_loss: 1.1569 | g_loss: 0.5764
# Epoch [   17/   35] | d_loss: 0.8585 | g_loss: 1.1539
# Epoch [   17/   35] | d_loss: 1.4131 | g_loss: 0.8311
# Epoch [   17/   35] | d_loss: 0.9037 | g_loss: 1.1715
# Epoch [   17/   35] | d_loss: 0.9247 | g_loss: 0.8665
# Epoch [   17/   35] | d_loss: 0.7991 | g_loss: 1.2313
# Epoch [   17/   35] | d_loss: 0.8216 | g_loss: 2.3350
# Epoch [   17/   35] | d_loss: 0.8297 | g_loss: 2.1055
# Epoch [   17/   35] | d_loss: 0.8536 | g_loss: 0.8965
# Epoch [   17/   35] | d_loss: 1.0041 | g_loss: 0.7470
# Epoch [   17/   35] | d_loss: 0.7931 | g_loss: 0.9222
# Epoch [   18/   35] | d_loss: 0.7215 | g_loss: 1.3063
# Epoch [   18/   35] | d_loss: 0.7834 | g_loss: 1.1884
# Epoch [   18/   35] | d_loss: 0.8614 | g_loss: 1.1792
# Epoch [   18/   35] | d_loss: 0.7716 | g_loss: 1.1907
# Epoch [   18/   35] | d_loss: 1.1591 | g_loss: 3.7816
# Epoch [   18/   35] | d_loss: 0.7898 | g_loss: 1.8675
# Epoch [   18/   35] | d_loss: 1.0120 | g_loss: 0.8897
# Epoch [   18/   35] | d_loss: 0.6667 | g_loss: 1.6407
# Epoch [   18/   35] | d_loss: 0.7824 | g_loss: 1.5157
# Epoch [   18/   35] | d_loss: 0.6817 | g_loss: 1.2147
# Epoch [   18/   35] | d_loss: 0.8573 | g_loss: 1.3268
# Epoch [   18/   35] | d_loss: 0.6935 | g_loss: 1.3574
# Epoch [   18/   35] | d_loss: 0.8758 | g_loss: 0.8858
# Epoch [   18/   35] | d_loss: 0.7860 | g_loss: 1.3292
# Epoch [   18/   35] | d_loss: 0.7216 | g_loss: 1.5068
# Epoch [   19/   35] | d_loss: 0.7442 | g_loss: 1.3575
# Epoch [   19/   35] | d_loss: 0.7173 | g_loss: 1.4053
# Epoch [   19/   35] | d_loss: 0.6453 | g_loss: 1.8944
# Epoch [   19/   35] | d_loss: 0.7307 | g_loss: 1.3072
# Epoch [   19/   35] | d_loss: 0.7849 | g_loss: 0.8465
# Epoch [   19/   35] | d_loss: 0.6034 | g_loss: 1.5710
# Epoch [   19/   35] | d_loss: 0.7570 | g_loss: 1.2455
# Epoch [   19/   35] | d_loss: 1.2859 | g_loss: 0.8960
# Epoch [   19/   35] | d_loss: 0.5599 | g_loss: 1.5548
# Epoch [   19/   35] | d_loss: 0.6891 | g_loss: 1.8199
# Epoch [   19/   35] | d_loss: 0.7167 | g_loss: 1.6312
# Epoch [   19/   35] | d_loss: 0.7307 | g_loss: 1.4624
# Epoch [   19/   35] | d_loss: 0.8890 | g_loss: 1.1365
# Epoch [   19/   35] | d_loss: 0.9307 | g_loss: 1.7908
# Epoch [   19/   35] | d_loss: 0.4774 | g_loss: 2.0126
# Epoch [   20/   35] | d_loss: 0.7284 | g_loss: 1.4506
# Epoch [   20/   35] | d_loss: 0.7025 | g_loss: 1.4373
# Epoch [   20/   35] | d_loss: 0.6407 | g_loss: 1.9611
# Epoch [   20/   35] | d_loss: 0.7914 | g_loss: 1.3942
# Epoch [   20/   35] | d_loss: 0.7783 | g_loss: 1.9642
# Epoch [   20/   35] | d_loss: 0.5937 | g_loss: 1.5320
# Epoch [   20/   35] | d_loss: 0.6042 | g_loss: 1.1701
# Epoch [   20/   35] | d_loss: 0.7262 | g_loss: 1.4131
# Epoch [   20/   35] | d_loss: 1.0568 | g_loss: 2.7224
# Epoch [   20/   35] | d_loss: 0.7528 | g_loss: 1.4273
# Epoch [   20/   35] | d_loss: 0.7596 | g_loss: 1.0676
# Epoch [   20/   35] | d_loss: 1.0776 | g_loss: 0.6581
# Epoch [   20/   35] | d_loss: 0.7088 | g_loss: 1.8700
# Epoch [   20/   35] | d_loss: 0.6428 | g_loss: 1.0908
# Epoch [   20/   35] | d_loss: 1.1505 | g_loss: 0.3817
# Epoch [   21/   35] | d_loss: 2.5389 | g_loss: 4.0678
# Epoch [   21/   35] | d_loss: 0.5833 | g_loss: 2.0590
# Epoch [   21/   35] | d_loss: 0.8770 | g_loss: 1.2736
# Epoch [   21/   35] | d_loss: 0.5943 | g_loss: 1.1763
# Epoch [   21/   35] | d_loss: 0.6811 | g_loss: 1.3947
# Epoch [   21/   35] | d_loss: 0.8226 | g_loss: 1.8699
# Epoch [   21/   35] | d_loss: 1.3312 | g_loss: 1.0287
# Epoch [   21/   35] | d_loss: 0.8129 | g_loss: 1.6014
# Epoch [   21/   35] | d_loss: 0.7970 | g_loss: 1.1942
# Epoch [   21/   35] | d_loss: 0.5813 | g_loss: 1.3771
# Epoch [   21/   35] | d_loss: 0.6713 | g_loss: 1.1515
# Epoch [   21/   35] | d_loss: 0.8498 | g_loss: 2.5809
# Epoch [   21/   35] | d_loss: 0.5730 | g_loss: 1.2692
# Epoch [   21/   35] | d_loss: 0.6439 | g_loss: 1.9099
# Epoch [   21/   35] | d_loss: 0.8433 | g_loss: 1.5775
# Epoch [   22/   35] | d_loss: 0.8678 | g_loss: 1.1967
# Epoch [   22/   35] | d_loss: 0.7733 | g_loss: 1.0720
# Epoch [   22/   35] | d_loss: 1.0037 | g_loss: 0.8243
# Epoch [   22/   35] | d_loss: 0.5976 | g_loss: 1.8912
# Epoch [   22/   35] | d_loss: 0.6166 | g_loss: 1.6839
# Epoch [   22/   35] | d_loss: 1.7768 | g_loss: 0.5794
# Epoch [   22/   35] | d_loss: 0.9274 | g_loss: 1.1093
# Epoch [   22/   35] | d_loss: 0.5713 | g_loss: 1.9004
# Epoch [   22/   35] | d_loss: 0.7504 | g_loss: 1.3315
# Epoch [   22/   35] | d_loss: 0.8929 | g_loss: 1.0204
# Epoch [   22/   35] | d_loss: 0.6052 | g_loss: 1.6697
# Epoch [   22/   35] | d_loss: 0.7893 | g_loss: 1.1932
# Epoch [   22/   35] | d_loss: 0.6060 | g_loss: 1.5044
# Epoch [   22/   35] | d_loss: 0.3885 | g_loss: 2.7673
# Epoch [   22/   35] | d_loss: 0.8176 | g_loss: 1.3789
# Epoch [   23/   35] | d_loss: 0.8831 | g_loss: 1.1726
# Epoch [   23/   35] | d_loss: 0.5616 | g_loss: 1.7959
# Epoch [   23/   35] | d_loss: 0.6964 | g_loss: 1.0614
# Epoch [   23/   35] | d_loss: 0.7283 | g_loss: 1.7205
# Epoch [   23/   35] | d_loss: 0.5990 | g_loss: 1.7494
# Epoch [   23/   35] | d_loss: 0.7444 | g_loss: 1.5247
# Epoch [   23/   35] | d_loss: 0.6631 | g_loss: 1.6090
# Epoch [   23/   35] | d_loss: 0.7636 | g_loss: 1.6649
# Epoch [   23/   35] | d_loss: 0.6034 | g_loss: 1.8768
# Epoch [   23/   35] | d_loss: 0.8467 | g_loss: 1.5740
# Epoch [   23/   35] | d_loss: 0.7438 | g_loss: 2.0110
# Epoch [   23/   35] | d_loss: 0.6825 | g_loss: 2.1726
# Epoch [   23/   35] | d_loss: 0.6674 | g_loss: 1.7794
# Epoch [   23/   35] | d_loss: 0.5217 | g_loss: 1.2568
# Epoch [   23/   35] | d_loss: 1.7314 | g_loss: 3.8000
# Epoch [   24/   35] | d_loss: 0.7223 | g_loss: 2.8663
# Epoch [   24/   35] | d_loss: 0.6961 | g_loss: 1.1617
# Epoch [   24/   35] | d_loss: 0.6881 | g_loss: 1.2712
# Epoch [   24/   35] | d_loss: 0.7778 | g_loss: 1.4091
# Epoch [   24/   35] | d_loss: 0.6397 | g_loss: 1.7019
# Epoch [   24/   35] | d_loss: 0.7248 | g_loss: 1.5985
# Epoch [   24/   35] | d_loss: 0.9902 | g_loss: 1.0263
# Epoch [   24/   35] | d_loss: 1.0585 | g_loss: 3.9862
# Epoch [   24/   35] | d_loss: 0.5127 | g_loss: 1.8330
# Epoch [   24/   35] | d_loss: 0.6012 | g_loss: 1.5941
# Epoch [   24/   35] | d_loss: 0.7189 | g_loss: 1.4053
# Epoch [   24/   35] | d_loss: 0.7368 | g_loss: 1.2794
# Epoch [   24/   35] | d_loss: 0.5919 | g_loss: 1.7550
# Epoch [   24/   35] | d_loss: 0.6482 | g_loss: 2.3657
# Epoch [   24/   35] | d_loss: 0.5483 | g_loss: 1.2457
# Epoch [   25/   35] | d_loss: 0.8752 | g_loss: 1.0247
# Epoch [   25/   35] | d_loss: 0.9343 | g_loss: 2.4090
# Epoch [   25/   35] | d_loss: 0.5212 | g_loss: 2.2958
# Epoch [   25/   35] | d_loss: 0.6417 | g_loss: 1.9416
# Epoch [   25/   35] | d_loss: 0.5786 | g_loss: 1.6107
# Epoch [   25/   35] | d_loss: 0.6762 | g_loss: 1.5504
# Epoch [   25/   35] | d_loss: 0.5816 | g_loss: 2.0606
# Epoch [   25/   35] | d_loss: 0.6146 | g_loss: 1.3313
# Epoch [   25/   35] | d_loss: 0.6250 | g_loss: 1.9286
# Epoch [   25/   35] | d_loss: 0.5674 | g_loss: 1.5268
# Epoch [   25/   35] | d_loss: 0.6873 | g_loss: 1.2077
# Epoch [   25/   35] | d_loss: 0.6740 | g_loss: 2.2704
# Epoch [   25/   35] | d_loss: 0.6707 | g_loss: 1.0462
# Epoch [   25/   35] | d_loss: 0.5965 | g_loss: 1.5790
# Epoch [   25/   35] | d_loss: 0.6553 | g_loss: 2.0948
# Epoch [   26/   35] | d_loss: 0.7124 | g_loss: 1.9817
# Epoch [   26/   35] | d_loss: 0.5401 | g_loss: 2.5861
# Epoch [   26/   35] | d_loss: 0.7342 | g_loss: 1.2188
# Epoch [   26/   35] | d_loss: 0.6211 | g_loss: 1.7322
# Epoch [   26/   35] | d_loss: 1.4143 | g_loss: 0.3903
# Epoch [   26/   35] | d_loss: 0.6388 | g_loss: 2.6073
# Epoch [   26/   35] | d_loss: 0.6539 | g_loss: 1.2443
# Epoch [   26/   35] | d_loss: 0.5523 | g_loss: 2.0004
# Epoch [   26/   35] | d_loss: 0.4611 | g_loss: 2.0521
# Epoch [   26/   35] | d_loss: 0.7223 | g_loss: 1.0870
# Epoch [   26/   35] | d_loss: 0.6856 | g_loss: 1.3238
# Epoch [   26/   35] | d_loss: 0.8051 | g_loss: 1.1254
# Epoch [   26/   35] | d_loss: 0.8045 | g_loss: 2.2010
# Epoch [   26/   35] | d_loss: 0.4467 | g_loss: 1.6993
# Epoch [   26/   35] | d_loss: 0.7019 | g_loss: 0.9675
# Epoch [   27/   35] | d_loss: 1.3845 | g_loss: 3.7514
# Epoch [   27/   35] | d_loss: 0.5585 | g_loss: 2.2452
# Epoch [   27/   35] | d_loss: 0.4581 | g_loss: 2.0055
# Epoch [   27/   35] | d_loss: 0.4790 | g_loss: 2.3128
# Epoch [   27/   35] | d_loss: 0.7537 | g_loss: 2.0517
# Epoch [   27/   35] | d_loss: 0.5852 | g_loss: 1.5072
# Epoch [   27/   35] | d_loss: 0.6205 | g_loss: 3.4228
# Epoch [   27/   35] | d_loss: 0.8727 | g_loss: 1.4794
# Epoch [   27/   35] | d_loss: 0.4538 | g_loss: 1.9988
# Epoch [   27/   35] | d_loss: 0.4999 | g_loss: 1.7317
# Epoch [   27/   35] | d_loss: 0.7193 | g_loss: 1.8149
# Epoch [   27/   35] | d_loss: 0.9385 | g_loss: 1.2501
# Epoch [   27/   35] | d_loss: 4.0907 | g_loss: 4.5520
# Epoch [   27/   35] | d_loss: 0.5501 | g_loss: 1.8140
# Epoch [   27/   35] | d_loss: 0.7832 | g_loss: 1.4969
# Epoch [   28/   35] | d_loss: 0.6183 | g_loss: 1.4301
# Epoch [   28/   35] | d_loss: 0.6738 | g_loss: 1.3635
# Epoch [   28/   35] | d_loss: 0.6260 | g_loss: 2.1064
# Epoch [   28/   35] | d_loss: 0.6332 | g_loss: 1.7954
# Epoch [   28/   35] | d_loss: 0.4986 | g_loss: 1.8183
# Epoch [   28/   35] | d_loss: 0.4472 | g_loss: 1.6773
# Epoch [   28/   35] | d_loss: 0.7245 | g_loss: 1.8268
# Epoch [   28/   35] | d_loss: 0.6239 | g_loss: 1.6573
# Epoch [   28/   35] | d_loss: 0.4497 | g_loss: 2.2790
# Epoch [   28/   35] | d_loss: 0.4648 | g_loss: 1.8148
# Epoch [   28/   35] | d_loss: 0.5747 | g_loss: 1.7897
# Epoch [   28/   35] | d_loss: 0.8921 | g_loss: 1.3541
# Epoch [   28/   35] | d_loss: 0.6179 | g_loss: 2.3785
# Epoch [   28/   35] | d_loss: 0.4481 | g_loss: 1.9649
# Epoch [   28/   35] | d_loss: 0.8130 | g_loss: 2.0385
# Epoch [   29/   35] | d_loss: 0.6351 | g_loss: 1.7564
# Epoch [   29/   35] | d_loss: 0.5625 | g_loss: 1.6463
# Epoch [   29/   35] | d_loss: 0.5108 | g_loss: 1.9684
# Epoch [   29/   35] | d_loss: 0.6018 | g_loss: 2.1132
# Epoch [   29/   35] | d_loss: 0.6535 | g_loss: 1.6968
# Epoch [   29/   35] | d_loss: 0.4634 | g_loss: 1.8291
# Epoch [   29/   35] | d_loss: 0.4571 | g_loss: 1.9063
# Epoch [   29/   35] | d_loss: 0.5783 | g_loss: 2.0393
# Epoch [   29/   35] | d_loss: 0.9367 | g_loss: 1.1354
# Epoch [   29/   35] | d_loss: 0.6845 | g_loss: 2.3646
# Epoch [   29/   35] | d_loss: 0.4003 | g_loss: 2.0077
# Epoch [   29/   35] | d_loss: 0.6810 | g_loss: 1.6116
# Epoch [   29/   35] | d_loss: 0.5459 | g_loss: 2.8820
# Epoch [   29/   35] | d_loss: 0.4808 | g_loss: 1.5124
# Epoch [   29/   35] | d_loss: 0.5645 | g_loss: 2.1693
# Epoch [   30/   35] | d_loss: 0.5586 | g_loss: 1.9639
# Epoch [   30/   35] | d_loss: 0.4923 | g_loss: 2.4798
# Epoch [   30/   35] | d_loss: 0.6083 | g_loss: 1.8770
# Epoch [   30/   35] | d_loss: 0.8808 | g_loss: 2.3567
# Epoch [   30/   35] | d_loss: 0.5743 | g_loss: 2.5259
# Epoch [   30/   35] | d_loss: 0.4150 | g_loss: 1.6672
# Epoch [   30/   35] | d_loss: 0.5009 | g_loss: 2.0571
# Epoch [   30/   35] | d_loss: 0.5805 | g_loss: 2.6425
# Epoch [   30/   35] | d_loss: 0.3905 | g_loss: 2.1421
# Epoch [   30/   35] | d_loss: 0.8198 | g_loss: 1.0760
# Epoch [   30/   35] | d_loss: 0.5449 | g_loss: 2.1282
# Epoch [   30/   35] | d_loss: 0.7577 | g_loss: 1.4521
# Epoch [   30/   35] | d_loss: 0.4827 | g_loss: 1.4603
# Epoch [   30/   35] | d_loss: 0.6438 | g_loss: 4.0276
# Epoch [   30/   35] | d_loss: 0.6259 | g_loss: 2.0636
# Epoch [   31/   35] | d_loss: 0.5171 | g_loss: 2.2276
# Epoch [   31/   35] | d_loss: 0.6229 | g_loss: 1.9127
# Epoch [   31/   35] | d_loss: 0.4440 | g_loss: 2.7169
# Epoch [   31/   35] | d_loss: 0.6366 | g_loss: 2.0257
# Epoch [   31/   35] | d_loss: 0.5859 | g_loss: 1.4532
# Epoch [   31/   35] | d_loss: 0.7958 | g_loss: 1.4891
# Epoch [   31/   35] | d_loss: 0.4425 | g_loss: 1.7718
# Epoch [   31/   35] | d_loss: 0.5238 | g_loss: 1.3341
# Epoch [   31/   35] | d_loss: 0.6536 | g_loss: 1.6503
# Epoch [   31/   35] | d_loss: 0.5378 | g_loss: 1.9808
# Epoch [   31/   35] | d_loss: 0.4326 | g_loss: 2.6086
# Epoch [   31/   35] | d_loss: 0.7025 | g_loss: 1.4579
# Epoch [   31/   35] | d_loss: 0.6340 | g_loss: 3.1802
# Epoch [   31/   35] | d_loss: 0.5195 | g_loss: 1.9071
# Epoch [   31/   35] | d_loss: 0.4637 | g_loss: 1.9461
# Epoch [   32/   35] | d_loss: 0.4998 | g_loss: 2.0884
# Epoch [   32/   35] | d_loss: 0.7144 | g_loss: 1.7966
# Epoch [   32/   35] | d_loss: 0.5220 | g_loss: 1.7822
# Epoch [   32/   35] | d_loss: 0.6453 | g_loss: 1.5148
# Epoch [   32/   35] | d_loss: 0.4126 | g_loss: 1.8799
# Epoch [   32/   35] | d_loss: 0.6223 | g_loss: 2.2616
# Epoch [   32/   35] | d_loss: 0.4342 | g_loss: 2.7206
# Epoch [   32/   35] | d_loss: 0.6011 | g_loss: 1.6733
# Epoch [   32/   35] | d_loss: 0.9104 | g_loss: 5.2469
# Epoch [   32/   35] | d_loss: 0.5743 | g_loss: 2.0142
# Epoch [   32/   35] | d_loss: 0.2701 | g_loss: 2.0647
# Epoch [   32/   35] | d_loss: 0.5444 | g_loss: 2.0966
# Epoch [   32/   35] | d_loss: 1.9724 | g_loss: 5.6615
# Epoch [   32/   35] | d_loss: 0.5336 | g_loss: 1.9024
# Epoch [   32/   35] | d_loss: 0.5418 | g_loss: 2.1688
# Epoch [   33/   35] | d_loss: 0.2736 | g_loss: 3.0381
# Epoch [   33/   35] | d_loss: 0.4151 | g_loss: 2.0911
# Epoch [   33/   35] | d_loss: 0.7099 | g_loss: 0.9210
# Epoch [   33/   35] | d_loss: 0.4168 | g_loss: 2.3342
# Epoch [   33/   35] | d_loss: 0.4121 | g_loss: 2.6628
# Epoch [   33/   35] | d_loss: 1.9157 | g_loss: 1.0065
# Epoch [   33/   35] | d_loss: 0.5086 | g_loss: 1.7753
# Epoch [   33/   35] | d_loss: 0.4695 | g_loss: 2.0844
# Epoch [   33/   35] | d_loss: 0.5145 | g_loss: 2.6847
# Epoch [   33/   35] | d_loss: 0.5129 | g_loss: 2.3287
# Epoch [   33/   35] | d_loss: 0.6460 | g_loss: 2.6781
# Epoch [   33/   35] | d_loss: 0.5432 | g_loss: 2.3253
# Epoch [   33/   35] | d_loss: 0.4458 | g_loss: 2.0151
# Epoch [   33/   35] | d_loss: 0.6434 | g_loss: 3.0064
# Epoch [   33/   35] | d_loss: 0.4125 | g_loss: 2.0298
# Epoch [   34/   35] | d_loss: 0.6219 | g_loss: 1.0971
# Epoch [   34/   35] | d_loss: 0.4684 | g_loss: 2.4105
# Epoch [   34/   35] | d_loss: 0.4506 | g_loss: 2.2034
# Epoch [   34/   35] | d_loss: 0.3471 | g_loss: 2.3624
# Epoch [   34/   35] | d_loss: 0.6828 | g_loss: 2.4400
# Epoch [   34/   35] | d_loss: 0.4263 | g_loss: 2.4960
# Epoch [   34/   35] | d_loss: 0.4601 | g_loss: 2.2811
# Epoch [   34/   35] | d_loss: 0.3996 | g_loss: 2.3916
# Epoch [   34/   35] | d_loss: 0.3670 | g_loss: 2.5052
# Epoch [   34/   35] | d_loss: 0.4719 | g_loss: 1.6855
# Epoch [   34/   35] | d_loss: 0.4603 | g_loss: 2.1345
# Epoch [   34/   35] | d_loss: 0.6448 | g_loss: 1.7290
# Epoch [   34/   35] | d_loss: 0.4689 | g_loss: 1.9122
# Epoch [   34/   35] | d_loss: 0.5506 | g_loss: 2.3272
# Epoch [   34/   35] | d_loss: 0.4322 | g_loss: 1.5595
# Epoch [   35/   35] | d_loss: 0.4828 | g_loss: 1.7320
# Epoch [   35/   35] | d_loss: 0.4741 | g_loss: 2.2598
# Epoch [   35/   35] | d_loss: 0.4307 | g_loss: 2.2123
# Epoch [   35/   35] | d_loss: 0.3660 | g_loss: 2.1245
# Epoch [   35/   35] | d_loss: 0.4757 | g_loss: 2.6519
# Epoch [   35/   35] | d_loss: 1.2397 | g_loss: 1.3673
# Epoch [   35/   35] | d_loss: 0.6449 | g_loss: 3.3162
# Epoch [   35/   35] | d_loss: 0.6440 | g_loss: 1.3658
# Epoch [   35/   35] | d_loss: 0.5163 | g_loss: 2.0006
# Epoch [   35/   35] | d_loss: 0.5099 | g_loss: 2.1962
# Epoch [   35/   35] | d_loss: 0.5432 | g_loss: 2.0244
# Epoch [   35/   35] | d_loss: 0.4253 | g_loss: 1.6802
# Epoch [   35/   35] | d_loss: 0.3570 | g_loss: 2.3903
# Epoch [   35/   35] | d_loss: 0.6522 | g_loss: 1.1432
# Epoch [   35/   35] | d_loss: 0.3177 | g_loss: 2.1372

# %% [markdown]
# ## Training loss
#
# Plot the training losses for the generator and discriminator, recorded after each epoch.

# %%
import pickle as pkl
import os

# Check current working directory
print(os.getcwd())

# Save training generator samples
with open('/home/daniel-diegel/deep-learning-v2-pytorch-master/project-face-generation/train_samples_2.pkl', 'wb') as f:
    pkl.dump(samples, f)
# Out:
# /home/daniel-diegel/deep-learning-v2-pytorch-master/project-face-generation

# %%
fig, ax = plt.subplots()
losses = np.array(losses)
plt.plot(losses.T[0], label='Discriminator', alpha=0.5)
plt.plot(losses.T[1], label='Generator', alpha=0.5)
plt.title("Training Losses")
plt.legend()

plt.savefig('training_loss_2.png', bbox_inches='tight', pad_inches=0)

# %% [markdown]
# ## Generator samples from training
#
# View samples of images from the generator, and answer a question about the strengths and weaknesses of your trained models.

# %%
# helper function for viewing a list of passed in sample images
def view_samples(epoch, samples):
    fig, axes = plt.subplots(figsize=(16,4), nrows=2, ncols=8, sharey=True, sharex=True)
    for ax, img in zip(axes.flatten(), samples[epoch]):
        img = img.detach().cpu().numpy()
        img = np.transpose(img, (1, 2, 0))
        img = ((img + 1)*255 / (2)).astype(np.uint8)
        ax.xaxis.set_visible(False)
        ax.yaxis.set_visible(False)
        im = ax.imshow(img.reshape((32,32,3)))

# %%
# Load samples from generator, taken while training
with open('train_samples_2.pkl', 'rb') as f:
    samples = pkl.load(f)
# Out:
# /home/daniel-diegel/mambaforge/envs/deep-learning/lib/python3.9/site-packages/torch/storage.py:414: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   return torch.load(io.BytesIO(b))

# %%
_ = view_samples(-1, samples)

plt.savefig('final_image_2.png', bbox_inches='tight', pad_inches=0)

# %% [markdown]
# ### Question: What do you notice about your generated samples and how might you improve this model?
# When you answer this question, consider the following factors:
# * The dataset is biased; it is made of "celebrity" faces that are mostly white
# * Model size; larger models have the opportunity to learn more features in a data feature space
# * Optimization strategy; optimizers and number of epochs affect your final result

# %% [markdown]
# **Answer:** (Write your answer in this cell)
# - Optimization Strategy: For GANs the Adam optimizer is the best from literature.
# - For further improvement a gardient clip could improve the process, since it limits the values of updating the weight and could leed to a better converge.
# - Also dropout could be used to archive a higher result

# %% [markdown]
# ### Submitting This Project
# When submitting this project, make sure to run all the cells before saving the notebook. Save the notebook file as "dlnd_face_generation.ipynb" and save it as a HTML file under "File" -> "Download as". Include the "problem_unittests.py" files in your submission.
